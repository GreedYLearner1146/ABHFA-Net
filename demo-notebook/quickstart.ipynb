# %%
# !git clone https://github.com/damianomarsili/VADAR.git
# %cd VADAR/demo-notebook
# Out:
# Cloning into 'VADAR'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 57 (delta 14), reused 25 (delta 5), pack-reused 7 (from 1)
# Receiving objects: 100% (57/57), 6.36 MiB | 23.92 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/VADAR/demo-notebook

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 121.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import sys
sys.path.append('.')   # so that notebook_imports.py can be found

# %%
# Make sure we're at /content
# %cd /content

# Remove if partially installed
# !rm -rf GroundingDINO

# Clone repo fresh
# !git clone https://github.com/IDEA-Research/GroundingDINO.git

# Check contents
# !ls /content/GroundingDINO
# !ls /content/GroundingDINO/groundingdino
# Out:
# /content
# Cloning into 'GroundingDINO'...
# remote: Enumerating objects: 463, done.
# remote: Total 463 (delta 0), reused 0 (delta 0), pack-reused 463 (from 1)
# Receiving objects: 100% (463/463), 12.91 MiB | 11.38 MiB/s, done.
# Resolving deltas: 100% (220/220), done.
# demo	    docker_test.py    groundingdino  README.md	       setup.py
# Dockerfile  environment.yaml  LICENSE	     requirements.txt  test.ipynb
# config	datasets  __init__.py  models  util

# %%
# !ls /content
# !ls /content/GroundingDINO
# Out:
# GroundingDINO  sample_data  VADAR
# demo	    docker_test.py    groundingdino  README.md	       setup.py
# Dockerfile  environment.yaml  LICENSE	     requirements.txt  test.ipynb

# %%
import importlib.util, os

print(os.path.exists("/content/GroundingDINO/groundingdino"))
spec = importlib.util.find_spec("groundingdino")
print("Found groundingdino?", spec is not None)
# Out:
# True
# Found groundingdino? True

# %%
import sys
sys.path.append("/content/GroundingDINO")

# %%
import importlib
importlib.invalidate_caches()

# %%
# Make sure you're in the right place
# %cd /content/VADAR/demo-notebook

# Check notebook_imports.py exists
# !ls
# Out:
# /content/VADAR/demo-notebook
# GroundingDINO  notebook_imports.py  __pycache__  quickstart.ipynb  resources

# %%
import groundingdino.datasets.transforms as T  # should work now

# %%
from notebook_imports import *
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3459581042.py in <cell line: 0>()
# ----> 1 from notebook_imports import *
#
# /content/VADAR/demo-notebook/notebook_imports.py in <module>
#      17 import torch
#      18 import io
# ---> 19 from unidepth.models import UniDepthV2
#      20 import base64
#      21 from PIL import Image, ImageDraw
#
# ModuleNotFoundError: No module named 'unidepth'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
